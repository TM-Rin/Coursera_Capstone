# %% [markdown]
# ## DATA

# %% [markdown]
# For our problem we are going to use Foursquare API to get required data.
#
# We are going to fetch venues, venue category for each neighbourhood in each borough in Moscow.

# %% [markdown]
# Venue fetch example:
# ![image.png](attachment:image.png)
